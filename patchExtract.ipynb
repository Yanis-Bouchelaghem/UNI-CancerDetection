# %% [markdown]
# # Imports

# %%
import xml.etree.ElementTree as ET
import numpy as np
import cv2
from PIL import Image, ImageDraw
import os
from pathlib import Path
import openslide
from shapely.geometry import Polygon, box
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon as MplPolygon, Rectangle
import matplotlib.patches as mpatches
from tqdm import tqdm
import json
import warnings
warnings.filterwarnings('ignore')

class WSICancerPatchExtractor:
    """
    Extracteur de patches depuis une WSI avec classification cancéreux/sain
    basée sur les annotations XML.
    """
    
    def __init__(self, wsi_path: str, xml_path: str, patch_size: int = 256):
        """
        Initialise l'extracteur.
        
        Args:
            wsi_path: Chemin vers le fichier TIFF de la WSI
            xml_path: Chemin vers le fichier XML d'annotations
            patch_size: Taille des patches (défaut: 256x256)
        """
        self.wsi_path = os.path.abspath(wsi_path)
        self.xml_path = os.path.abspath(xml_path)
        self.patch_size = patch_size
        self.annotations = []
        self.wsi = None
        self.use_openslide = False
        
        # Vérifier que les fichiers existent
        if not os.path.exists(self.wsi_path):
            raise FileNotFoundError(f"Fichier WSI non trouvé : {self.wsi_path}")
        if not os.path.exists(self.xml_path):
            raise FileNotFoundError(f"Fichier XML non trouvé : {self.xml_path}")
    
    def load_wsi(self):
        """Charge la WSI avec OpenSlide ou PIL."""
        try:
            self.wsi = openslide.OpenSlide(self.wsi_path)
            self.use_openslide = True
            print(f"✓ WSI chargée avec OpenSlide")
            print(f"  Dimensions : {self.wsi.dimensions}")
            print(f"  Niveaux : {self.wsi.level_count}")
        except Exception as e:
            print(f"OpenSlide non disponible : {e}")
            print("Chargement avec PIL...")
            self.wsi = Image.open(self.wsi_path)
            self.use_openslide = False
            print(f"✓ Image chargée avec PIL")
            print(f"  Dimensions : {self.wsi.size}")
    
    def parse_xml_annotations(self):
        """Parse le fichier XML et extrait les annotations de polygones."""
        tree = ET.parse(self.xml_path)
        root = tree.getroot()
        
        self.annotations = []
        
        for annotation in root.findall('.//Annotation'):
            if annotation.get('Type') == 'Polygon':
                name = annotation.get('Name')
                color = annotation.get('Color')
                group = annotation.get('PartOfGroup')
                
                coordinates = []
                for coord in annotation.findall('.//Coordinate'):
                    x = float(coord.get('X'))
                    y = float(coord.get('Y'))
                    coordinates.append((x, y))
                
                if coordinates:
                    polygon = Polygon(coordinates)
                    self.annotations.append({
                        'name': name,
                        'color': color,
                        'group': group,
                        'coordinates': coordinates,
                        'polygon': polygon,
                        'bounds': polygon.bounds  # (minx, miny, maxx, maxy)
                    })
        
        print(f"✓ {len(self.annotations)} annotations trouvées dans le XML")
        return self.annotations
    
    def extract_annotation_region(self, annotation, padding=50):
        """
        Extrait la région contenant une annotation avec padding.
        
        Args:
            annotation: Dictionnaire d'annotation
            padding: Pixels de padding autour de la région
            
        Returns:
            region_image: Image numpy de la région
            region_bounds: (x, y, width, height) de la région extraite
        """
        minx, miny, maxx, maxy = annotation['bounds']
        
        # Ajouter le padding
        x = max(0, int(minx - padding))
        y = max(0, int(miny - padding))
        
        if self.use_openslide:
            w = min(self.wsi.dimensions[0] - x, int(maxx - minx + 2 * padding))
            h = min(self.wsi.dimensions[1] - y, int(maxy - miny + 2 * padding))
            region = self.wsi.read_region((x, y), 0, (w, h))
            region = region.convert('RGB')
        else:
            w = min(self.wsi.size[0] - x, int(maxx - minx + 2 * padding))
            h = min(self.wsi.size[1] - y, int(maxy - miny + 2 * padding))
            region = self.wsi.crop((x, y, x + w, y + h))
        
        return np.array(region), (x, y, w, h)
    
    def create_mask_for_annotation(self, annotation, region_bounds):
        """
        Crée un masque binaire pour l'annotation dans une région donnée.
        
        Args:
            annotation: Dictionnaire d'annotation
            region_bounds: (x, y, w, h) de la région
            
        Returns:
            mask: Masque binaire numpy
        """
        x, y, w, h = region_bounds
        mask = np.zeros((h, w), dtype=np.uint8)
        
        # Ajuster les coordonnées au repère de la région
        adjusted_coords = []
        for px, py in annotation['coordinates']:
            adj_x = int(px - x)
            adj_y = int(py - y)
            if 0 <= adj_x < w and 0 <= adj_y < h:
                adjusted_coords.append([adj_x, adj_y])
        
        if adjusted_coords:
            pts = np.array(adjusted_coords, dtype=np.int32)
            cv2.fillPoly(mask, [pts], 255)
        
        return mask
    
    def visualize_annotation_region(self, annotation, save_path=None):
        """
        Visualise une région annotée avec overlay semi-transparent.
        
        Args:
            annotation: Dictionnaire d'annotation
            save_path: Chemin pour sauvegarder la visualisation (optionnel)
        """
        # Extraire la région
        region_img, region_bounds = self.extract_annotation_region(annotation)
        x, y, w, h = region_bounds
        
        # Créer le masque
        mask = self.create_mask_for_annotation(annotation, region_bounds)
        
        # Créer l'overlay rouge semi-transparent
        overlay = region_img.copy()
        overlay[mask > 0] = [255, 0, 0]  # Rouge pour les zones cancéreuses
        
        # Mélanger l'image originale et l'overlay
        alpha = 0.3
        result = cv2.addWeighted(region_img, 1 - alpha, overlay, alpha, 0)
        
        # Dessiner le contour
        contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        cv2.drawContours(result, contours, -1, (255, 0, 0), 3)
        
        # Afficher
        plt.figure(figsize=(12, 8))
        plt.imshow(result)
        plt.title(f"Annotation: {annotation['name']} (Groupe: {annotation['group']})")
        plt.axis('off')
        
        if save_path:
            plt.savefig(save_path, dpi=150, bbox_inches='tight')
            plt.close()
        else:
            plt.show()
        
        return result, mask
    
    def extract_patches_from_region(self, region_img, mask, region_bounds):
        """
        Découpe une région en patches et calcule le pourcentage de tissu cancéreux.
        
        Args:
            region_img: Image numpy de la région
            mask: Masque binaire de l'annotation
            region_bounds: (x, y, w, h) de la région dans l'image complète
            
        Returns:
            patches_cancer: Liste de patches cancéreux (>= 20% de tissu annoté)
            patches_sain: Liste de patches sains (< 20% de tissu annoté)
            patches_info: Informations sur chaque patch
        """
        x_offset, y_offset, _, _ = region_bounds
        patches_cancer = []
        patches_sain = []
        patches_info = []
        
        h, w = region_img.shape[:2]
        
        # Parcourir la région avec une fenêtre glissante
        for y in range(0, h - self.patch_size + 1, self.patch_size):
            for x in range(0, w - self.patch_size + 1, self.patch_size):
                # Extraire le patch
                patch = region_img[y:y + self.patch_size, x:x + self.patch_size]
                
                # Extraire la partie correspondante du masque
                patch_mask = mask[y:y + self.patch_size, x:x + self.patch_size]
                
                # Calculer le pourcentage de pixels cancéreux
                cancer_pixels = np.sum(patch_mask > 0)
                total_pixels = self.patch_size * self.patch_size
                cancer_percentage = (cancer_pixels / total_pixels) * 100
                
                # Position globale du patch dans la WSI
                global_x = x + x_offset
                global_y = y + y_offset
                
                # Convertir les types numpy en types Python standard pour JSON
                patch_info = {
                    'global_position': (int(global_x), int(global_y)),
                    'cancer_percentage': float(cancer_percentage),
                    'is_cancer': bool(cancer_percentage >= 20)  # Conversion explicite en bool Python
                }
                
                if cancer_percentage >= 20:
                    patches_cancer.append(patch)
                else:
                    patches_sain.append(patch)
                
                patches_info.append(patch_info)
        
        return patches_cancer, patches_sain, patches_info
    
    def process_all_annotations(self, output_dir):
        """
        Traite toutes les annotations et sauvegarde les patches.
        
        Args:
            output_dir: Répertoire de sortie principal
        """
        # Créer les dossiers de sortie
        output_dir = Path(output_dir)
        cancer_dir = output_dir / "tissu_cancereux"
        sain_dir = output_dir / "tissu_sain"
        viz_dir = output_dir / "visualisations"
        
        for dir_path in [cancer_dir, sain_dir, viz_dir]:
            dir_path.mkdir(parents=True, exist_ok=True)
        
        # Statistiques globales
        total_patches_cancer = 0
        total_patches_sain = 0
        all_patches_info = []
        
        # Traiter chaque annotation
        print("\nTraitement des annotations...")
        for idx, annotation in enumerate(self.annotations):
            print(f"\n--- Annotation {idx + 1}/{len(self.annotations)}: {annotation['name']} ---")
            
            # Visualiser et sauvegarder la région annotée
            viz_path = viz_dir / f"annotation_{annotation['name']}_{idx}.png"
            result_img, mask = self.visualize_annotation_region(annotation, save_path=viz_path)
            
            # Extraire la région
            region_img, region_bounds = self.extract_annotation_region(annotation)
            
            # Recréer le masque pour cette région
            mask = self.create_mask_for_annotation(annotation, region_bounds)
            
            # Extraire les patches
            patches_cancer, patches_sain, patches_info = self.extract_patches_from_region(
                region_img, mask, region_bounds
            )
            
            # Sauvegarder les patches cancéreux
            for patch_idx, patch in enumerate(patches_cancer):
                filename = f"ann{idx}_{annotation['name']}_patch{patch_idx}_cancer.png"
                Image.fromarray(patch).save(cancer_dir / filename)
            
            # Sauvegarder les patches sains
            for patch_idx, patch in enumerate(patches_sain):
                filename = f"ann{idx}_{annotation['name']}_patch{patch_idx}_sain.png"
                Image.fromarray(patch).save(sain_dir / filename)
            
            # Ajouter les infos de cette annotation
            for info in patches_info:
                info['annotation_idx'] = idx
                info['annotation_name'] = annotation['name']
            all_patches_info.extend(patches_info)
            
            # Statistiques
            total_patches_cancer += len(patches_cancer)
            total_patches_sain += len(patches_sain)
            
            print(f"  Patches cancéreux: {len(patches_cancer)}")
            print(f"  Patches sains: {len(patches_sain)}")
        
        # Sauvegarder les métadonnées
        metadata = {
            'patch_size': self.patch_size,
            'total_annotations': len(self.annotations),
            'total_patches_cancer': total_patches_cancer,
            'total_patches_sain': total_patches_sain,
            'patches_info': all_patches_info
        }
        
        # Sauvegarder en JSON
        try:
            with open(output_dir / 'metadata.json', 'w') as f:
                json.dump(metadata, f, indent=2)
        except Exception as e:
            print(f"Erreur lors de la sauvegarde des métadonnées : {e}")
        
        # Afficher le résumé
        print("\n=== RÉSUMÉ ===")
        print(f"Annotations traitées: {len(self.annotations)}")
        print(f"Total patches cancéreux: {total_patches_cancer}")
        print(f"Total patches sains: {total_patches_sain}")
        if total_patches_cancer + total_patches_sain > 0:
            ratio = total_patches_cancer/(total_patches_cancer + total_patches_sain)
            print(f"Ratio cancer/sain: {ratio:.2%}")
        
        return all_patches_info
    
    def create_patch_overview(self, patches_info, output_path, downsample=32):
        """
        Crée une vue d'ensemble montrant l'emplacement des patches cancéreux/sains.
        
        Args:
            patches_info: Liste des informations sur les patches
            output_path: Chemin de sauvegarde
            downsample: Facteur de réduction pour la visualisation
        """
        # Obtenir une miniature de la WSI
        if self.use_openslide:
            thumb_size = (self.wsi.dimensions[0] // downsample, 
                         self.wsi.dimensions[1] // downsample)
            thumbnail = self.wsi.get_thumbnail(thumb_size)
        else:
            thumb_size = (self.wsi.size[0] // downsample, 
                         self.wsi.size[1] // downsample)
            thumbnail = self.wsi.resize(thumb_size, Image.Resampling.LANCZOS)
        
        # Créer la figure
        fig, ax = plt.subplots(1, 1, figsize=(15, 15))
        ax.imshow(thumbnail)
        
        # Dessiner les patches
        for patch_info in patches_info:
            x, y = patch_info['global_position']
            x_scaled = x / downsample
            y_scaled = y / downsample
            size_scaled = self.patch_size / downsample
            
            # Couleur selon le type
            if patch_info['is_cancer']:
                color = 'red'
                alpha = 0.5
            else:
                color = 'green'
                alpha = 0.3
            
            rect = Rectangle((x_scaled, y_scaled), size_scaled, size_scaled,
                           linewidth=1, edgecolor=color, facecolor=color, alpha=alpha)
            ax.add_patch(rect)
        
        # Ajouter les contours des annotations
        for annotation in self.annotations:
            scaled_coords = [(x/downsample, y/downsample) 
                           for x, y in annotation['coordinates']]
            poly = MplPolygon(scaled_coords, fill=False, edgecolor='blue', 
                            linewidth=2, linestyle='--')
            ax.add_patch(poly)
        
        # Légende
        red_patch = mpatches.Patch(color='red', alpha=0.5, label='Tissu cancéreux (≥20%)')
        green_patch = mpatches.Patch(color='green', alpha=0.3, label='Tissu sain (<20%)')
        blue_line = mpatches.Patch(color='blue', label='Contour des annotations')
        ax.legend(handles=[red_patch, green_patch, blue_line], loc='upper right')
        
        ax.set_title(f"Vue d'ensemble des patches ({self.patch_size}x{self.patch_size} pixels)")
        ax.axis('off')
        
        plt.savefig(output_path, dpi=150, bbox_inches='tight')
        plt.close()
        print(f"✓ Vue d'ensemble sauvegardée : {output_path}")


# Fonction principale pour exécuter tout le pipeline
def main(wsi_path, xml_path, output_dir="patches_output", patch_size=256):
    """
    Fonction principale pour exécuter l'extraction complète.
    
    Args:
        wsi_path: Chemin vers le fichier TIFF
        xml_path: Chemin vers le fichier XML
        output_dir: Répertoire de sortie
        patch_size: Taille des patches (défaut: 256)
    """
    print("=== Démarrage de l'extraction des patches ===\n")
    
    try:
        # Créer l'extracteur
        extractor = WSICancerPatchExtractor(wsi_path, xml_path, patch_size)
        
        # Charger la WSI
        extractor.load_wsi()
        
        # Parser les annotations
        extractor.parse_xml_annotations()
        
        # Traiter toutes les annotations
        patches_info = extractor.process_all_annotations(output_dir)
        
        # Créer une vue d'ensemble
        if patches_info:
            overview_path = Path(output_dir) / "vue_ensemble_patches.png"
            extractor.create_patch_overview(patches_info, overview_path)
        
        print(f"\n✓ Extraction terminée ! Résultats dans : {output_dir}")
        
    except Exception as e:
        print(f"\n❌ Erreur : {e}")
        import traceback
        traceback.print_exc()


# Script d'exemple
if __name__ == "__main__":
    # === MODIFIEZ CES CHEMINS ===
    wsi_path = "d:/Wsi/tumor_111.tif"           # Remplacez par le chemin de votre image TIFF
    xml_path = "d:/Wsi/annot/tumor_111.xml"     # Remplacez par le chemin de votre fichier XML
    output_dir = "d:/Wsi/extracted_regions"     # Dossier où seront sauvegardés les résultats
    patch_size = 256                            # Taille des patches (modifiable)
    
    # Vérifier que les fichiers existent avant de lancer
    from pathlib import Path
    
    if not Path(wsi_path).exists():
        print(f"❌ Fichier WSI non trouvé : {wsi_path}")
        print("Veuillez modifier le chemin 'wsi_path' dans le script")
    elif not Path(xml_path).exists():
        print(f"❌ Fichier XML non trouvé : {xml_path}")
        print("Veuillez modifier le chemin 'xml_path' dans le script")
    else:
        # Lancer l'extraction
        main(wsi_path, xml_path, output_dir, patch_size)
# Out:
# === Démarrage de l'extraction des patches ===
#
# ✓ WSI chargée avec OpenSlide
#   Dimensions : (97792, 220672)
#   Niveaux : 10
# ✓ 9 annotations trouvées dans le XML
#
# Traitement des annotations...
#
# --- Annotation 1/9: Annotation 1 ---
#   Patches cancéreux: 146
#   Patches sains: 158
#
# --- Annotation 2/9: Annotation 2 ---
#   Patches cancéreux: 4
#   Patches sains: 0
#
# --- Annotation 3/9: Annotation 3 ---
#   Patches cancéreux: 0
#   Patches sains: 0
#
# --- Annotation 4/9: Annotation 4 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# --- Annotation 5/9: Annotation 5 ---
#   Patches cancéreux: 5
#   Patches sains: 1
#
# --- Annotation 6/9: Annotation 6 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# --- Annotation 7/9: Annotation 7 ---
#   Patches cancéreux: 0
#   Patches sains: 0
#
# --- Annotation 8/9: Annotation 8 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# --- Annotation 9/9: Annotation 9 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# === RÉSUMÉ ===
# Annotations traitées: 9
# Total patches cancéreux: 159
# Total patches sains: 159
# Ratio cancer/sain: 50.00%
# ✓ Vue d'ensemble sauvegardée : d:\Wsi\extracted_regions\vue_ensemble_patches.png
#
# ✓ Extraction terminée ! Résultats dans : d:/Wsi/extracted_regions

# %%
import xml.etree.ElementTree as ET
import numpy as np
import cv2
from PIL import Image, ImageDraw
import os
from pathlib import Path
import openslide
from shapely.geometry import Polygon, box
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon as MplPolygon, Rectangle
import matplotlib.patches as mpatches
from tqdm import tqdm
import json
import warnings
import glob
import pandas as pd
from datetime import datetime
warnings.filterwarnings('ignore')

# Importer la classe principale depuis le fichier précédent
# (Copiez ici toute la classe WSICancerPatchExtractor du code précédent)

class WSICancerPatchExtractor:
    """
    Extracteur de patches depuis une WSI avec classification cancéreux/sain
    basée sur les annotations XML.
    """
    
    def __init__(self, wsi_path: str, xml_path: str, patch_size: int = 256):
        """
        Initialise l'extracteur.
        
        Args:
            wsi_path: Chemin vers le fichier TIFF de la WSI
            xml_path: Chemin vers le fichier XML d'annotations
            patch_size: Taille des patches (défaut: 256x256)
        """
        self.wsi_path = os.path.abspath(wsi_path)
        self.xml_path = os.path.abspath(xml_path)
        self.patch_size = patch_size
        self.annotations = []
        self.wsi = None
        self.use_openslide = False
        
        # Vérifier que les fichiers existent
        if not os.path.exists(self.wsi_path):
            raise FileNotFoundError(f"Fichier WSI non trouvé : {self.wsi_path}")
        if not os.path.exists(self.xml_path):
            raise FileNotFoundError(f"Fichier XML non trouvé : {self.xml_path}")
    
    def load_wsi(self):
        """Charge la WSI avec OpenSlide ou PIL."""
        try:
            self.wsi = openslide.OpenSlide(self.wsi_path)
            self.use_openslide = True
            print(f"✓ WSI chargée avec OpenSlide")
            print(f"  Dimensions : {self.wsi.dimensions}")
            print(f"  Niveaux : {self.wsi.level_count}")
        except Exception as e:
            print(f"OpenSlide non disponible : {e}")
            print("Chargement avec PIL...")
            self.wsi = Image.open(self.wsi_path)
            self.use_openslide = False
            print(f"✓ Image chargée avec PIL")
            print(f"  Dimensions : {self.wsi.size}")
    
    def parse_xml_annotations(self):
        """Parse le fichier XML et extrait les annotations de polygones."""
        tree = ET.parse(self.xml_path)
        root = tree.getroot()
        
        self.annotations = []
        
        for annotation in root.findall('.//Annotation'):
            if annotation.get('Type') in ['Polygon', 'Spline']:
                name = annotation.get('Name')
                color = annotation.get('Color')
                group = annotation.get('PartOfGroup')
                
                coordinates = []
                for coord in annotation.findall('.//Coordinate'):
                    x = float(coord.get('X'))
                    y = float(coord.get('Y'))
                    coordinates.append((x, y))
                
                if coordinates:
                    polygon = Polygon(coordinates)
                    self.annotations.append({
                        'name': name,
                        'color': color,
                        'group': group,
                        'coordinates': coordinates,
                        'polygon': polygon,
                        'bounds': polygon.bounds  # (minx, miny, maxx, maxy)
                    })
        
        print(f"✓ {len(self.annotations)} annotations trouvées dans le XML")
        return self.annotations
    
    def extract_annotation_region(self, annotation, padding=50):
        """
        Extrait la région contenant une annotation avec padding.
        
        Args:
            annotation: Dictionnaire d'annotation
            padding: Pixels de padding autour de la région
            
        Returns:
            region_image: Image numpy de la région
            region_bounds: (x, y, width, height) de la région extraite
        """
        minx, miny, maxx, maxy = annotation['bounds']
        
        # Ajouter le padding
        x = max(0, int(minx - padding))
        y = max(0, int(miny - padding))
        
        if self.use_openslide:
            w = min(self.wsi.dimensions[0] - x, int(maxx - minx + 2 * padding))
            h = min(self.wsi.dimensions[1] - y, int(maxy - miny + 2 * padding))
            region = self.wsi.read_region((x, y), 0, (w, h))
            region = region.convert('RGB')
        else:
            w = min(self.wsi.size[0] - x, int(maxx - minx + 2 * padding))
            h = min(self.wsi.size[1] - y, int(maxy - miny + 2 * padding))
            region = self.wsi.crop((x, y, x + w, y + h))
        
        return np.array(region), (x, y, w, h)
    
    def create_mask_for_annotation(self, annotation, region_bounds):
        """
        Crée un masque binaire pour l'annotation dans une région donnée.
        
        Args:
            annotation: Dictionnaire d'annotation
            region_bounds: (x, y, w, h) de la région
            
        Returns:
            mask: Masque binaire numpy
        """
        x, y, w, h = region_bounds
        mask = np.zeros((h, w), dtype=np.uint8)
        
        # Ajuster les coordonnées au repère de la région
        adjusted_coords = []
        for px, py in annotation['coordinates']:
            adj_x = int(px - x)
            adj_y = int(py - y)
            if 0 <= adj_x < w and 0 <= adj_y < h:
                adjusted_coords.append([adj_x, adj_y])
        
        if adjusted_coords:
            pts = np.array(adjusted_coords, dtype=np.int32)
            cv2.fillPoly(mask, [pts], 255)
        
        return mask
    
    def visualize_annotation_region(self, annotation, save_path=None):
        """
        Visualise une région annotée avec overlay semi-transparent.
        
        Args:
            annotation: Dictionnaire d'annotation
            save_path: Chemin pour sauvegarder la visualisation (optionnel)
        """
        # Extraire la région
        region_img, region_bounds = self.extract_annotation_region(annotation)
        x, y, w, h = region_bounds
        
        # Créer le masque
        mask = self.create_mask_for_annotation(annotation, region_bounds)
        
        # Créer l'overlay rouge semi-transparent
        overlay = region_img.copy()
        overlay[mask > 0] = [255, 0, 0]  # Rouge pour les zones cancéreuses
        
        # Mélanger l'image originale et l'overlay
        alpha = 0.3
        result = cv2.addWeighted(region_img, 1 - alpha, overlay, alpha, 0)
        
        # Dessiner le contour
        contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        cv2.drawContours(result, contours, -1, (255, 0, 0), 3)
        
        # Afficher
        plt.figure(figsize=(12, 8))
        plt.imshow(result)
        plt.title(f"Annotation: {annotation['name']} (Groupe: {annotation['group']})")
        plt.axis('off')
        
        if save_path:
            plt.savefig(save_path, dpi=150, bbox_inches='tight')
            plt.close()
        else:
            plt.show()
        
        return result, mask
    
    def extract_patches_from_region(self, region_img, mask, region_bounds):
        """
        Découpe une région en patches et calcule le pourcentage de tissu cancéreux.
        
        Args:
            region_img: Image numpy de la région
            mask: Masque binaire de l'annotation
            region_bounds: (x, y, w, h) de la région dans l'image complète
            
        Returns:
            patches_cancer: Liste de patches cancéreux (>= 20% de tissu annoté)
            patches_sain: Liste de patches sains (< 20% de tissu annoté)
            patches_info: Informations sur chaque patch
        """
        x_offset, y_offset, _, _ = region_bounds
        patches_cancer = []
        patches_sain = []
        patches_info = []
        
        h, w = region_img.shape[:2]
        
        # Parcourir la région avec une fenêtre glissante
        for y in range(0, h - self.patch_size + 1, self.patch_size):
            for x in range(0, w - self.patch_size + 1, self.patch_size):
                # Extraire le patch
                patch = region_img[y:y + self.patch_size, x:x + self.patch_size]
                
                # Extraire la partie correspondante du masque
                patch_mask = mask[y:y + self.patch_size, x:x + self.patch_size]
                
                # Calculer le pourcentage de pixels cancéreux
                cancer_pixels = np.sum(patch_mask > 0)
                total_pixels = self.patch_size * self.patch_size
                cancer_percentage = (cancer_pixels / total_pixels) * 100
                
                # Position globale du patch dans la WSI
                global_x = x + x_offset
                global_y = y + y_offset
                
                # Convertir les types numpy en types Python standard pour JSON
                patch_info = {
                    'global_position': (int(global_x), int(global_y)),
                    'cancer_percentage': float(cancer_percentage),
                    'is_cancer': bool(cancer_percentage >= 20)  # Conversion explicite en bool Python
                }
                
                if cancer_percentage >= 20:
                    patches_cancer.append(patch)
                else:
                    patches_sain.append(patch)
                
                patches_info.append(patch_info)
        
        return patches_cancer, patches_sain, patches_info
    
    def process_all_annotations(self, output_dir):
        """
        Traite toutes les annotations et sauvegarde les patches.
        
        Args:
            output_dir: Répertoire de sortie principal
        """
        # Créer les dossiers de sortie
        output_dir = Path(output_dir)
        cancer_dir = output_dir / "tissu_cancereux"
        sain_dir = output_dir / "tissu_sain"
        viz_dir = output_dir / "visualisations"
        
        for dir_path in [cancer_dir, sain_dir, viz_dir]:
            dir_path.mkdir(parents=True, exist_ok=True)
        
        # Statistiques globales
        total_patches_cancer = 0
        total_patches_sain = 0
        all_patches_info = []
        
        # Traiter chaque annotation
        print("\nTraitement des annotations...")
        for idx, annotation in enumerate(self.annotations):
            print(f"\n--- Annotation {idx + 1}/{len(self.annotations)}: {annotation['name']} ---")
            
            # Visualiser et sauvegarder la région annotée
            viz_path = viz_dir / f"annotation_{annotation['name']}_{idx}.png"
            result_img, mask = self.visualize_annotation_region(annotation, save_path=viz_path)
            
            # Extraire la région
            region_img, region_bounds = self.extract_annotation_region(annotation)
            
            # Recréer le masque pour cette région
            mask = self.create_mask_for_annotation(annotation, region_bounds)
            
            # Extraire les patches
            patches_cancer, patches_sain, patches_info = self.extract_patches_from_region(
                region_img, mask, region_bounds
            )
            
            # Sauvegarder les patches cancéreux
            for patch_idx, patch in enumerate(patches_cancer):
                filename = f"ann{idx}_{annotation['name']}_patch{patch_idx}_cancer.png"
                Image.fromarray(patch).save(cancer_dir / filename)
            
            # Sauvegarder les patches sains
            for patch_idx, patch in enumerate(patches_sain):
                filename = f"ann{idx}_{annotation['name']}_patch{patch_idx}_sain.png"
                Image.fromarray(patch).save(sain_dir / filename)
            
            # Ajouter les infos de cette annotation
            for info in patches_info:
                info['annotation_idx'] = idx
                info['annotation_name'] = annotation['name']
            all_patches_info.extend(patches_info)
            
            # Statistiques
            total_patches_cancer += len(patches_cancer)
            total_patches_sain += len(patches_sain)
            
            print(f"  Patches cancéreux: {len(patches_cancer)}")
            print(f"  Patches sains: {len(patches_sain)}")
        
        # Sauvegarder les métadonnées
        metadata = {
            'patch_size': self.patch_size,
            'total_annotations': len(self.annotations),
            'total_patches_cancer': total_patches_cancer,
            'total_patches_sain': total_patches_sain,
            'patches_info': all_patches_info
        }
        
        # Sauvegarder en JSON
        try:
            with open(output_dir / 'metadata.json', 'w') as f:
                json.dump(metadata, f, indent=2)
        except Exception as e:
            print(f"Erreur lors de la sauvegarde des métadonnées : {e}")
        
        # Afficher le résumé
        print("\n=== RÉSUMÉ ===")
        print(f"Annotations traitées: {len(self.annotations)}")
        print(f"Total patches cancéreux: {total_patches_cancer}")
        print(f"Total patches sains: {total_patches_sain}")
        if total_patches_cancer + total_patches_sain > 0:
            ratio = total_patches_cancer/(total_patches_cancer + total_patches_sain)
            print(f"Ratio cancer/sain: {ratio:.2%}")
        
        return all_patches_info
    
    def create_patch_overview(self, patches_info, output_path, downsample=32):
        """
        Crée une vue d'ensemble montrant l'emplacement des patches cancéreux/sains.
        
        Args:
            patches_info: Liste des informations sur les patches
            output_path: Chemin de sauvegarde
            downsample: Facteur de réduction pour la visualisation
        """
        # Obtenir une miniature de la WSI
        if self.use_openslide:
            thumb_size = (self.wsi.dimensions[0] // downsample, 
                         self.wsi.dimensions[1] // downsample)
            thumbnail = self.wsi.get_thumbnail(thumb_size)
        else:
            thumb_size = (self.wsi.size[0] // downsample, 
                         self.wsi.size[1] // downsample)
            thumbnail = self.wsi.resize(thumb_size, Image.Resampling.LANCZOS)
        
        # Créer la figure
        fig, ax = plt.subplots(1, 1, figsize=(15, 15))
        ax.imshow(thumbnail)
        
        # Dessiner les patches
        for patch_info in patches_info:
            x, y = patch_info['global_position']
            x_scaled = x / downsample
            y_scaled = y / downsample
            size_scaled = self.patch_size / downsample
            
            # Couleur selon le type
            if patch_info['is_cancer']:
                color = 'red'
                alpha = 0.5
            else:
                color = 'green'
                alpha = 0.3
            
            rect = Rectangle((x_scaled, y_scaled), size_scaled, size_scaled,
                           linewidth=1, edgecolor=color, facecolor=color, alpha=alpha)
            ax.add_patch(rect)
        
        # Ajouter les contours des annotations
        for annotation in self.annotations:
            scaled_coords = [(x/downsample, y/downsample) 
                           for x, y in annotation['coordinates']]
            poly = MplPolygon(scaled_coords, fill=False, edgecolor='blue', 
                            linewidth=2, linestyle='--')
            ax.add_patch(poly)
        
        # Légende
        red_patch = mpatches.Patch(color='red', alpha=0.5, label='Tissu cancéreux (≥20%)')
        green_patch = mpatches.Patch(color='green', alpha=0.3, label='Tissu sain (<20%)')
        blue_line = mpatches.Patch(color='blue', label='Contour des annotations')
        ax.legend(handles=[red_patch, green_patch, blue_line], loc='upper right')
        
        ax.set_title(f"Vue d'ensemble des patches ({self.patch_size}x{self.patch_size} pixels)")
        ax.axis('off')
        
        plt.savefig(output_path, dpi=150, bbox_inches='tight')
        plt.close()
        print(f"✓ Vue d'ensemble sauvegardée : {output_path}")


# === NOUVELLES FONCTIONS POUR LE TRAITEMENT EN BATCH ===

def process_single_wsi(wsi_path, xml_path, output_dir, patch_size=256):
    """
    Traite un seul fichier WSI et retourne les statistiques.
    
    Args:
        wsi_path: Chemin du fichier TIFF
        xml_path: Chemin du fichier XML
        output_dir: Dossier de sortie principal
        patch_size: Taille des patches
        
    Returns:
        dict: Statistiques du traitement
    """
    # Nom de base du fichier pour créer un sous-dossier
    base_name = Path(wsi_path).stem
    specific_output_dir = Path(output_dir) / base_name
    
    print(f"\n{'='*60}")
    print(f"Traitement de : {base_name}")
    print(f"{'='*60}")
    
    try:
        # Créer l'extracteur
        extractor = WSICancerPatchExtractor(wsi_path, xml_path, patch_size)
        
        # Charger la WSI
        extractor.load_wsi()
        
        # Parser les annotations
        extractor.parse_xml_annotations()
        
        # Traiter toutes les annotations
        patches_info = extractor.process_all_annotations(specific_output_dir)
        
        # Créer une vue d'ensemble
        if patches_info:
            overview_path = specific_output_dir / "vue_ensemble_patches.png"
            extractor.create_patch_overview(patches_info, overview_path)
        
        # Calculer les statistiques
        total_cancer = sum(1 for p in patches_info if p['is_cancer'])
        total_sain = sum(1 for p in patches_info if not p['is_cancer'])
        
        stats = {
            'file': base_name,
            'status': 'success',
            'annotations': len(extractor.annotations),
            'patches_cancer': total_cancer,
            'patches_sain': total_sain,
            'total_patches': total_cancer + total_sain,
            'ratio_cancer': total_cancer / (total_cancer + total_sain) if (total_cancer + total_sain) > 0 else 0,
            'output_dir': str(specific_output_dir)
        }
        
        print(f"✓ Traitement terminé pour {base_name}")
        
    except Exception as e:
        print(f"❌ Erreur lors du traitement de {base_name}: {e}")
        stats = {
            'file': base_name,
            'status': 'error',
            'error': str(e)
        }
    
    return stats


def process_batch_from_list(file_pairs, output_dir, patch_size=256):
    """
    Traite une liste de paires (wsi_path, xml_path).
    
    Args:
        file_pairs: Liste de tuples (wsi_path, xml_path)
        output_dir: Dossier de sortie principal
        patch_size: Taille des patches
    """
    print(f"\n=== TRAITEMENT EN BATCH DE {len(file_pairs)} FICHIERS ===\n")
    
    # Créer le dossier de sortie principal
    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)
    
    # Statistiques globales
    all_stats = []
    
    # Traiter chaque fichier
    for i, (wsi_path, xml_path) in enumerate(file_pairs, 1):
        print(f"\nFichier {i}/{len(file_pairs)}")
        stats = process_single_wsi(wsi_path, xml_path, output_dir, patch_size)
        all_stats.append(stats)
    
    # Sauvegarder le rapport global
    report_path = output_dir / f"rapport_batch_{datetime.now().strftime('%Y%m%d_%H%M%S')}.json"
    with open(report_path, 'w') as f:
        json.dump(all_stats, f, indent=2)
    
    # Créer un rapport CSV
    df = pd.DataFrame(all_stats)
    csv_path = output_dir / f"rapport_batch_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"
    df.to_csv(csv_path, index=False)
    
    # Afficher le résumé
    print("\n" + "="*60)
    print("RÉSUMÉ DU TRAITEMENT BATCH")
    print("="*60)
    
    success_count = sum(1 for s in all_stats if s.get('status') == 'success')
    error_count = sum(1 for s in all_stats if s.get('status') == 'error')
    
    print(f"Fichiers traités avec succès : {success_count}/{len(file_pairs)}")
    print(f"Fichiers avec erreurs : {error_count}/{len(file_pairs)}")
    
    if success_count > 0:
        total_cancer = sum(s.get('patches_cancer', 0) for s in all_stats if s.get('status') == 'success')
        total_sain = sum(s.get('patches_sain', 0) for s in all_stats if s.get('status') == 'success')
        
        print(f"\nTotal patches cancéreux : {total_cancer}")
        print(f"Total patches sains : {total_sain}")
        print(f"Ratio global cancer/sain : {total_cancer/(total_cancer + total_sain):.2%}" if (total_cancer + total_sain) > 0 else "")
    
    print(f"\nRapports sauvegardés :")
    print(f"  - {report_path}")
    print(f"  - {csv_path}")


def process_batch_from_directory(wsi_dir, xml_dir, output_dir, patch_size=256):
    """
    Traite tous les fichiers .tif d'un dossier avec leurs XML correspondants.
    
    Args:
        wsi_dir: Dossier contenant les fichiers .tif
        xml_dir: Dossier contenant les fichiers .xml
        output_dir: Dossier de sortie
        patch_size: Taille des patches
    """
    # Trouver tous les fichiers .tif
    wsi_files = glob.glob(os.path.join(wsi_dir, "*.tif"))
    
    # Créer les paires de fichiers
    file_pairs = []
    missing_xml = []
    
    for wsi_path in wsi_files:
        base_name = Path(wsi_path).stem
        xml_path = os.path.join(xml_dir, f"{base_name}.xml")
        
        if os.path.exists(xml_path):
            file_pairs.append((wsi_path, xml_path))
        else:
            missing_xml.append(base_name)
    
    print(f"Fichiers trouvés : {len(wsi_files)}")
    print(f"Paires complètes : {len(file_pairs)}")
    
    if missing_xml:
        print(f"\n⚠️ Fichiers XML manquants pour : {', '.join(missing_xml)}")
    
    if file_pairs:
        process_batch_from_list(file_pairs, output_dir, patch_size)
    else:
        print("❌ Aucune paire de fichiers valide trouvée.")


# === EXEMPLES D'UTILISATION ===

if __name__ == "__main__":
    # === OPTION 1 : LISTE MANUELLE DE FICHIERS ===
    # Définir manuellement les fichiers à traiter
    # file_pairs = [
    #     ("d:/Wsi/tumor_111.tif", "d:/Wsi/annot/tumor_111.xml"),
    #     ("d:/Wsi/tumor_112.tif", "d:/Wsi/annot/tumor_112.xml"),
    #     ("d:/Wsi/tumor_113.tif", "d:/Wsi/annot/tumor_113.xml"),
    #     # Ajoutez autant de paires que nécessaire
    # ]
    
    # output_dir = "d:/Wsi/extracted_regions_batch"
    # patch_size = 256
    
    # # Traiter la liste
    # process_batch_from_list(file_pairs, output_dir, patch_size)
    
    # === OPTION 2 : TRAITER TOUS LES FICHIERS D'UN DOSSIER ===
    wsi_dir = "..\\dataset\\Camelyon dataset\\test"  # Dossier contenant les .tif
    xml_dir = "..\\dataset\\Camelyon dataset\\annot"  # Dossier contenant les .xml
    output_dir = "..\\dataset\\test_dataset_patches"
    patch_size = 224
    
    process_batch_from_directory(wsi_dir, xml_dir, output_dir, patch_size)
    
    # === OPTION 3 : TRAITER DEPUIS UN FICHIER CSV ===
    # Si vous avez un fichier CSV avec les chemins :
    # df = pd.read_csv("liste_fichiers.csv")
    # file_pairs = [(row['wsi_path'], row['xml_path']) for _, row in df.iterrows()]
    # process_batch_from_list(file_pairs, output_dir, patch_size)
# Out:
# Fichiers trouvés : 21
# Paires complètes : 21
#
# === TRAITEMENT EN BATCH DE 21 FICHIERS ===
#
#
# Fichier 1/21
#
# ============================================================
# Traitement de : tumor_002
# ============================================================
# ✓ WSI chargée avec OpenSlide
#   Dimensions : (97792, 219648)
#   Niveaux : 10
# ✓ 1 annotations trouvées dans le XML
#
# Traitement des annotations...
#
# --- Annotation 1/1: _0 ---
#   Patches cancéreux: 25
#   Patches sains: 25
#
# === RÉSUMÉ ===
# Annotations traitées: 1
# Total patches cancéreux: 25
# Total patches sains: 25
# Ratio cancer/sain: 50.00%
# ✓ Vue d'ensemble sauvegardée : ..\dataset\train_dataset_patches\tumor_002\vue_ensemble_patches.png
# ✓ Traitement terminé pour tumor_002
#
# Fichier 2/21
#
# ============================================================
# Traitement de : tumor_006
# ============================================================
# ✓ WSI chargée avec OpenSlide
#   Dimensions : (97792, 221184)
#   Niveaux : 10
# ✓ 5 annotations trouvées dans le XML
#
# Traitement des annotations...
#
# --- Annotation 1/5: _0 ---
#   Patches cancéreux: 4
#   Patches sains: 2
#
# --- Annotation 2/5: _1 ---
#   Patches cancéreux: 26
#   Patches sains: 46
#
# --- Annotation 3/5: _2 ---
#   Patches cancéreux: 8
#   Patches sains: 7
#
# --- Annotation 4/5: _3 ---
#   Patches cancéreux: 23
#   Patches sains: 7
#
# --- Annotation 5/5: _4 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# === RÉSUMÉ ===
# Annotations traitées: 5
# Total patches cancéreux: 62
# Total patches sains: 62
# Ratio cancer/sain: 50.00%
# ✓ Vue d'ensemble sauvegardée : ..\dataset\train_dataset_patches\tumor_006\vue_ensemble_patches.png
# ✓ Traitement terminé pour tumor_006
#
# Fichier 3/21
#
# ============================================================
# Traitement de : tumor_007
# ============================================================
# ✓ WSI chargée avec OpenSlide
#   Dimensions : (97792, 221184)
#   Niveaux : 10
# ✓ 9 annotations trouvées dans le XML
#
# Traitement des annotations...
#
# --- Annotation 1/9: _0 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# --- Annotation 2/9: _1 ---
#   Patches cancéreux: 13
#   Patches sains: 22
#
# --- Annotation 3/9: _2 ---
#   Patches cancéreux: 2
#   Patches sains: 0
#
# --- Annotation 4/9: _3 ---
#   Patches cancéreux: 0
#   Patches sains: 0
#
# --- Annotation 5/9: _4 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# --- Annotation 6/9: _5 ---
#   Patches cancéreux: 2
#   Patches sains: 0
#
# --- Annotation 7/9: _6 ---
#   Patches cancéreux: 2
#   Patches sains: 0
#
# --- Annotation 8/9: _7 ---
#   Patches cancéreux: 42
#   Patches sains: 35
#
# --- Annotation 9/9: _8 ---
#   Patches cancéreux: 0
#   Patches sains: 0
#
# === RÉSUMÉ ===
# Annotations traitées: 9
# Total patches cancéreux: 63
# Total patches sains: 57
# Ratio cancer/sain: 52.50%
# ✓ Vue d'ensemble sauvegardée : ..\dataset\train_dataset_patches\tumor_007\vue_ensemble_patches.png
# ✓ Traitement terminé pour tumor_007
#
# Fichier 4/21
#
# ============================================================
# Traitement de : tumor_008
# ============================================================
# ✓ WSI chargée avec OpenSlide
#   Dimensions : (97792, 221184)
#   Niveaux : 10
# ✓ 7 annotations trouvées dans le XML
#
# Traitement des annotations...
#
# --- Annotation 1/7: _0 ---
#   Patches cancéreux: 5
#   Patches sains: 1
#
# --- Annotation 2/7: _1 ---
#   Patches cancéreux: 2
#   Patches sains: 0
#
# --- Annotation 3/7: _2 ---
#   Patches cancéreux: 1
#   Patches sains: 1
#
# --- Annotation 4/7: _3 ---
#   Patches cancéreux: 4
#   Patches sains: 0
#
# --- Annotation 5/7: _4 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# --- Annotation 6/7: _5 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# --- Annotation 7/7: _6 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# === RÉSUMÉ ===
# Annotations traitées: 7
# Total patches cancéreux: 15
# Total patches sains: 2
# Ratio cancer/sain: 88.24%
# ✓ Vue d'ensemble sauvegardée : ..\dataset\train_dataset_patches\tumor_008\vue_ensemble_patches.png
# ✓ Traitement terminé pour tumor_008
#
# Fichier 5/21
#
# ============================================================
# Traitement de : tumor_019
# ============================================================
# ✓ WSI chargée avec OpenSlide
#   Dimensions : (97792, 219648)
#   Niveaux : 10
# ✓ 4 annotations trouvées dans le XML
#
# Traitement des annotations...
#
# --- Annotation 1/4: _0 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# --- Annotation 2/4: _1 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# --- Annotation 3/4: _2 ---
#   Patches cancéreux: 0
#   Patches sains: 0
#
# --- Annotation 4/4: _3 ---
#   Patches cancéreux: 74
#   Patches sains: 22
#
# === RÉSUMÉ ===
# Annotations traitées: 4
# Total patches cancéreux: 76
# Total patches sains: 22
# Ratio cancer/sain: 77.55%
# ✓ Vue d'ensemble sauvegardée : ..\dataset\train_dataset_patches\tumor_019\vue_ensemble_patches.png
# ✓ Traitement terminé pour tumor_019
#
# Fichier 6/21
#
# ============================================================
# Traitement de : tumor_022
# ============================================================
# ✓ WSI chargée avec OpenSlide
#   Dimensions : (96768, 221184)
#   Niveaux : 10
# ✓ 2 annotations trouvées dans le XML
#
# Traitement des annotations...
#
# --- Annotation 1/2: _0 ---
#   Patches cancéreux: 8
#   Patches sains: 4
#
# --- Annotation 2/2: _1 ---
#   Patches cancéreux: 99
#   Patches sains: 77
#
# === RÉSUMÉ ===
# Annotations traitées: 2
# Total patches cancéreux: 107
# Total patches sains: 81
# Ratio cancer/sain: 56.91%
# ✓ Vue d'ensemble sauvegardée : ..\dataset\train_dataset_patches\tumor_022\vue_ensemble_patches.png
# ✓ Traitement terminé pour tumor_022
#
# Fichier 7/21
#
# ============================================================
# Traitement de : tumor_028
# ============================================================
# ✓ WSI chargée avec OpenSlide
#   Dimensions : (97792, 221184)
#   Niveaux : 10
# ✓ 10 annotations trouvées dans le XML
#
# Traitement des annotations...
#
# --- Annotation 1/10: _0 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# --- Annotation 2/10: _1 ---
#   Patches cancéreux: 3
#   Patches sains: 1
#
# --- Annotation 3/10: _2 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# --- Annotation 4/10: _3 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# --- Annotation 5/10: _4 ---
#   Patches cancéreux: 21
#   Patches sains: 21
#
# --- Annotation 6/10: _5 ---
#   Patches cancéreux: 5
#   Patches sains: 1
#
# --- Annotation 7/10: _6 ---
#   Patches cancéreux: 4
#   Patches sains: 0
#
# --- Annotation 8/10: _7 ---
#   Patches cancéreux: 2
#   Patches sains: 0
#
# --- Annotation 9/10: _8 ---
#   Patches cancéreux: 8
#   Patches sains: 1
#
# --- Annotation 10/10: _9 ---
#   Patches cancéreux: 5
#   Patches sains: 1
#
# === RÉSUMÉ ===
# Annotations traitées: 10
# Total patches cancéreux: 51
# Total patches sains: 25
# Ratio cancer/sain: 67.11%
# ✓ Vue d'ensemble sauvegardée : ..\dataset\train_dataset_patches\tumor_028\vue_ensemble_patches.png
# ✓ Traitement terminé pour tumor_028
#
# Fichier 8/21
#
# ============================================================
# Traitement de : tumor_030
# ============================================================
# ✓ WSI chargée avec OpenSlide
#   Dimensions : (97792, 220672)
#   Niveaux : 10
# ✓ 1 annotations trouvées dans le XML
#
# Traitement des annotations...
#
# --- Annotation 1/1: _0 ---
#   Patches cancéreux: 9
#   Patches sains: 3
#
# === RÉSUMÉ ===
# Annotations traitées: 1
# Total patches cancéreux: 9
# Total patches sains: 3
# Ratio cancer/sain: 75.00%
# ✓ Vue d'ensemble sauvegardée : ..\dataset\train_dataset_patches\tumor_030\vue_ensemble_patches.png
# ✓ Traitement terminé pour tumor_030
#
# Fichier 9/21
#
# ============================================================
# Traitement de : tumor_040
# ============================================================
# ✓ WSI chargée avec OpenSlide
#   Dimensions : (97792, 214016)
#   Niveaux : 10
# ✓ 5 annotations trouvées dans le XML
#
# Traitement des annotations...
#
# --- Annotation 1/5: _0 ---
#   Patches cancéreux: 9
#   Patches sains: 5
#
# --- Annotation 2/5: _1 ---
#   Patches cancéreux: 2
#   Patches sains: 0
#
# --- Annotation 3/5: _2 ---
#   Patches cancéreux: 2
#   Patches sains: 0
#
# --- Annotation 4/5: _3 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# --- Annotation 5/5: _4 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# === RÉSUMÉ ===
# Annotations traitées: 5
# Total patches cancéreux: 15
# Total patches sains: 5
# Ratio cancer/sain: 75.00%
# ✓ Vue d'ensemble sauvegardée : ..\dataset\train_dataset_patches\tumor_040\vue_ensemble_patches.png
# ✓ Traitement terminé pour tumor_040
#
# Fichier 10/21
#
# ============================================================
# Traitement de : tumor_041
# ============================================================
# ✓ WSI chargée avec OpenSlide
#   Dimensions : (97792, 221184)
#   Niveaux : 10
# ✓ 6 annotations trouvées dans le XML
#
# Traitement des annotations...
#
# --- Annotation 1/6: _0 ---
#   Patches cancéreux: 15
#   Patches sains: 3
#
# --- Annotation 2/6: _1 ---
#   Patches cancéreux: 13
#   Patches sains: 5
#
# --- Annotation 3/6: _2 ---
#   Patches cancéreux: 9
#   Patches sains: 9
#
# --- Annotation 4/6: _3 ---
#   Patches cancéreux: 6
#   Patches sains: 2
#
# --- Annotation 5/6: _4 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# --- Annotation 6/6: _5 ---
#   Patches cancéreux: 22
#   Patches sains: 26
#
# === RÉSUMÉ ===
# Annotations traitées: 6
# Total patches cancéreux: 66
# Total patches sains: 45
# Ratio cancer/sain: 59.46%
# ✓ Vue d'ensemble sauvegardée : ..\dataset\train_dataset_patches\tumor_041\vue_ensemble_patches.png
# ✓ Traitement terminé pour tumor_041
#
# Fichier 11/21
#
# ============================================================
# Traitement de : tumor_042
# ============================================================
# ✓ WSI chargée avec OpenSlide
#   Dimensions : (97792, 221184)
#   Niveaux : 10
# ✓ 1 annotations trouvées dans le XML
#
# Traitement des annotations...
#
# --- Annotation 1/1: _0 ---
#   Patches cancéreux: 950
#   Patches sains: 555
#
# === RÉSUMÉ ===
# Annotations traitées: 1
# Total patches cancéreux: 950
# Total patches sains: 555
# Ratio cancer/sain: 63.12%
# ✓ Vue d'ensemble sauvegardée : ..\dataset\train_dataset_patches\tumor_042\vue_ensemble_patches.png
# ✓ Traitement terminé pour tumor_042
#
# Fichier 12/21
#
# ============================================================
# Traitement de : tumor_043
# ============================================================
# ✓ WSI chargée avec OpenSlide
#   Dimensions : (97792, 221184)
#   Niveaux : 10
# ✓ 1 annotations trouvées dans le XML
#
# Traitement des annotations...
#
# --- Annotation 1/1: _0 ---
#   Patches cancéreux: 8
#   Patches sains: 4
#
# === RÉSUMÉ ===
# Annotations traitées: 1
# Total patches cancéreux: 8
# Total patches sains: 4
# Ratio cancer/sain: 66.67%
# ✓ Vue d'ensemble sauvegardée : ..\dataset\train_dataset_patches\tumor_043\vue_ensemble_patches.png
# ✓ Traitement terminé pour tumor_043
#
# Fichier 13/21
#
# ============================================================
# Traitement de : tumor_044
# ============================================================
# ✓ WSI chargée avec OpenSlide
#   Dimensions : (97792, 221184)
#   Niveaux : 10
# ✓ 13 annotations trouvées dans le XML
#
# Traitement des annotations...
#
# --- Annotation 1/13: _0 ---
#   Patches cancéreux: 452
#   Patches sains: 398
#
# --- Annotation 2/13: _1 ---
#   Patches cancéreux: 5
#   Patches sains: 1
#
# --- Annotation 3/13: _2 ---
#   Patches cancéreux: 535
#   Patches sains: 356
#
# --- Annotation 4/13: _3 ---
#   Patches cancéreux: 68
#   Patches sains: 20
#
# --- Annotation 5/13: _4 ---
#   Patches cancéreux: 13
#   Patches sains: 7
#
# --- Annotation 6/13: _5 ---
#   Patches cancéreux: 23
#   Patches sains: 7
#
# --- Annotation 7/13: _6 ---
#   Patches cancéreux: 63
#   Patches sains: 145
#
# --- Annotation 8/13: _7 ---
#   Patches cancéreux: 134
#   Patches sains: 76
#
# --- Annotation 9/13: _8 ---
#   Patches cancéreux: 21
#   Patches sains: 9
#
# --- Annotation 10/13: _9 ---
#   Patches cancéreux: 16248
#   Patches sains: 11222
#
# --- Annotation 11/13: _10 ---
#   Patches cancéreux: 141
#   Patches sains: 101
#
# --- Annotation 12/13: _11 ---
#   Patches cancéreux: 4128
#   Patches sains: 2734
#
# --- Annotation 13/13: _12 ---
#   Patches cancéreux: 26
#   Patches sains: 10
#
# === RÉSUMÉ ===
# Annotations traitées: 13
# Total patches cancéreux: 21857
# Total patches sains: 15086
# Ratio cancer/sain: 59.16%
# ✓ Vue d'ensemble sauvegardée : ..\dataset\train_dataset_patches\tumor_044\vue_ensemble_patches.png
# ✓ Traitement terminé pour tumor_044
#
# Fichier 14/21
#
# ============================================================
# Traitement de : tumor_045
# ============================================================
# ✓ WSI chargée avec OpenSlide
#   Dimensions : (97792, 220160)
#   Niveaux : 10
# ✓ 2 annotations trouvées dans le XML
#
# Traitement des annotations...
#
# --- Annotation 1/2: _0 ---
#   Patches cancéreux: 140
#   Patches sains: 85
#
# --- Annotation 2/2: Annotation 1 ---
#   Patches cancéreux: 139
#   Patches sains: 77
#
# === RÉSUMÉ ===
# Annotations traitées: 2
# Total patches cancéreux: 279
# Total patches sains: 162
# Ratio cancer/sain: 63.27%
# ✓ Vue d'ensemble sauvegardée : ..\dataset\train_dataset_patches\tumor_045\vue_ensemble_patches.png
# ✓ Traitement terminé pour tumor_045
#
# Fichier 15/21
#
# ============================================================
# Traitement de : tumor_046
# ============================================================
# ✓ WSI chargée avec OpenSlide
#   Dimensions : (97792, 220672)
#   Niveaux : 10
# ✓ 5 annotations trouvées dans le XML
#
# Traitement des annotations...
#
# --- Annotation 1/5: _0 ---
#   Patches cancéreux: 11514
#   Patches sains: 9419
#
# --- Annotation 2/5: _1 ---
#   Patches cancéreux: 2023
#   Patches sains: 1337
#
# --- Annotation 3/5: _2 ---
#   Patches cancéreux: 1957
#   Patches sains: 1877
#
# --- Annotation 4/5: _3 ---
#   Patches cancéreux: 1118
#   Patches sains: 825
#
# --- Annotation 5/5: _4 ---
#   Patches cancéreux: 962
#   Patches sains: 1129
#
# === RÉSUMÉ ===
# Annotations traitées: 5
# Total patches cancéreux: 17574
# Total patches sains: 14587
# Ratio cancer/sain: 54.64%
# ✓ Vue d'ensemble sauvegardée : ..\dataset\train_dataset_patches\tumor_046\vue_ensemble_patches.png
# ✓ Traitement terminé pour tumor_046
#
# Fichier 16/21
#
# ============================================================
# Traitement de : tumor_047
# ============================================================
# ✓ WSI chargée avec OpenSlide
#   Dimensions : (97792, 211456)
#   Niveaux : 10
# ✓ 67 annotations trouvées dans le XML
#
# Traitement des annotations...
#
# --- Annotation 1/67: _0 ---
#   Patches cancéreux: 926
#   Patches sains: 714
#
# --- Annotation 2/67: _1 ---
#   Patches cancéreux: 156
#   Patches sains: 124
#
# --- Annotation 3/67: _2 ---
#   Patches cancéreux: 34
#   Patches sains: 15
#
# --- Annotation 4/67: _3 ---
#   Patches cancéreux: 38
#   Patches sains: 10
#
# --- Annotation 5/67: _4 ---
#   Patches cancéreux: 301
#   Patches sains: 275
#
# --- Annotation 6/67: _5 ---
#   Patches cancéreux: 1682
#   Patches sains: 480
#
# --- Annotation 7/67: _6 ---
#   Patches cancéreux: 1884
#   Patches sains: 1301
#
# --- Annotation 8/67: _7 ---
#   Patches cancéreux: 2578
#   Patches sains: 785
#
# --- Annotation 9/67: _8 ---
#   Patches cancéreux: 1532
#   Patches sains: 904
#
# --- Annotation 10/67: _9 ---
#   Patches cancéreux: 963
#   Patches sains: 481
#
# --- Annotation 11/67: _10 ---
#   Patches cancéreux: 6
#   Patches sains: 0
#
# --- Annotation 12/67: _11 ---
#   Patches cancéreux: 6
#   Patches sains: 2
#
# --- Annotation 13/67: _12 ---
#   Patches cancéreux: 161
#   Patches sains: 94
#
# --- Annotation 14/67: _13 ---
#   Patches cancéreux: 688
#   Patches sains: 432
#
# --- Annotation 15/67: _14 ---
#   Patches cancéreux: 5
#   Patches sains: 3
#
# --- Annotation 16/67: _15 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# --- Annotation 17/67: _16 ---
#   Patches cancéreux: 6
#   Patches sains: 0
#
# --- Annotation 18/67: _17 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# --- Annotation 19/67: _18 ---
#   Patches cancéreux: 67
#   Patches sains: 73
#
# --- Annotation 20/67: _19 ---
#   Patches cancéreux: 7
#   Patches sains: 1
#
# --- Annotation 21/67: _20 ---
#   Patches cancéreux: 437
#   Patches sains: 213
#
# --- Annotation 22/67: _21 ---
#   Patches cancéreux: 0
#   Patches sains: 0
#
# --- Annotation 23/67: _22 ---
#   Patches cancéreux: 583
#   Patches sains: 440
#
# --- Annotation 24/67: _23 ---
#   Patches cancéreux: 9
#   Patches sains: 3
#
# --- Annotation 25/67: _24 ---
#   Patches cancéreux: 2
#   Patches sains: 0
#
# --- Annotation 26/67: _25 ---
#   Patches cancéreux: 3
#   Patches sains: 0
#
# --- Annotation 27/67: _26 ---
#   Patches cancéreux: 233
#   Patches sains: 199
#
# --- Annotation 28/67: _27 ---
#   Patches cancéreux: 4
#   Patches sains: 5
#
# --- Annotation 29/67: _28 ---
#   Patches cancéreux: 41
#   Patches sains: 39
#
# --- Annotation 30/67: _29 ---
#   Patches cancéreux: 44
#   Patches sains: 26
#
# --- Annotation 31/67: _30 ---
#   Patches cancéreux: 0
#   Patches sains: 0
#
# --- Annotation 32/67: _31 ---
#   Patches cancéreux: 5
#   Patches sains: 3
#
# --- Annotation 33/67: _32 ---
#   Patches cancéreux: 2
#   Patches sains: 0
#
# --- Annotation 34/67: _33 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# --- Annotation 35/67: _34 ---
#   Patches cancéreux: 2
#   Patches sains: 0
#
# --- Annotation 36/67: _35 ---
#   Patches cancéreux: 12
#   Patches sains: 4
#
# --- Annotation 37/67: _36 ---
#   Patches cancéreux: 4
#   Patches sains: 0
#
# --- Annotation 38/67: _37 ---
#   Patches cancéreux: 2
#   Patches sains: 0
#
# --- Annotation 39/67: _38 ---
#   Patches cancéreux: 3
#   Patches sains: 1
#
# --- Annotation 40/67: _39 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# --- Annotation 41/67: _40 ---
#   Patches cancéreux: 2
#   Patches sains: 0
#
# --- Annotation 42/67: _41 ---
#   Patches cancéreux: 2
#   Patches sains: 0
#
# --- Annotation 43/67: _42 ---
#   Patches cancéreux: 0
#   Patches sains: 0
#
# --- Annotation 44/67: _43 ---
#   Patches cancéreux: 0
#   Patches sains: 0
#
# --- Annotation 45/67: _44 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# --- Annotation 46/67: _45 ---
#   Patches cancéreux: 0
#   Patches sains: 0
#
# --- Annotation 47/67: _46 ---
#   Patches cancéreux: 41
#   Patches sains: 31
#
# --- Annotation 48/67: _47 ---
#   Patches cancéreux: 4
#   Patches sains: 2
#
# --- Annotation 49/67: _48 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# --- Annotation 50/67: _49 ---
#   Patches cancéreux: 0
#   Patches sains: 0
#
# --- Annotation 51/67: _50 ---
#   Patches cancéreux: 0
#   Patches sains: 0
#
# --- Annotation 52/67: _51 ---
#   Patches cancéreux: 2
#   Patches sains: 2
#
# --- Annotation 53/67: _52 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# --- Annotation 54/67: _53 ---
#   Patches cancéreux: 1
#   Patches sains: 1
#
# --- Annotation 55/67: _54 ---
#   Patches cancéreux: 5
#   Patches sains: 1
#
# --- Annotation 56/67: _55 ---
#   Patches cancéreux: 11
#   Patches sains: 9
#
# --- Annotation 57/67: _56 ---
#   Patches cancéreux: 10
#   Patches sains: 5
#
# --- Annotation 58/67: _57 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# --- Annotation 59/67: _58 ---
#   Patches cancéreux: 21
#   Patches sains: 3
#
# --- Annotation 60/67: _59 ---
#   Patches cancéreux: 3
#   Patches sains: 1
#
# --- Annotation 61/67: _60 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# --- Annotation 62/67: _61 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# --- Annotation 63/67: _62 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# --- Annotation 64/67: _63 ---
#   Patches cancéreux: 0
#   Patches sains: 0
#
# --- Annotation 65/67: _64 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# --- Annotation 66/67: _65 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# --- Annotation 67/67: _66 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# === RÉSUMÉ ===
# Annotations traitées: 67
# Total patches cancéreux: 12542
# Total patches sains: 6682
# Ratio cancer/sain: 65.24%
# ✓ Vue d'ensemble sauvegardée : ..\dataset\train_dataset_patches\tumor_047\vue_ensemble_patches.png
# ✓ Traitement terminé pour tumor_047
#
# Fichier 17/21
#
# ============================================================
# Traitement de : tumor_048
# ============================================================
# ✓ WSI chargée avec OpenSlide
#   Dimensions : (97792, 217088)
#   Niveaux : 10
# ✓ 3 annotations trouvées dans le XML
#
# Traitement des annotations...
#
# --- Annotation 1/3: _0 ---
#   Patches cancéreux: 26
#   Patches sains: 10
#
# --- Annotation 2/3: _1 ---
#   Patches cancéreux: 15
#   Patches sains: 3
#
# --- Annotation 3/3: _2 ---
#   Patches cancéreux: 9
#   Patches sains: 1
#
# === RÉSUMÉ ===
# Annotations traitées: 3
# Total patches cancéreux: 50
# Total patches sains: 14
# Ratio cancer/sain: 78.12%
# ✓ Vue d'ensemble sauvegardée : ..\dataset\train_dataset_patches\tumor_048\vue_ensemble_patches.png
# ✓ Traitement terminé pour tumor_048
#
# Fichier 18/21
#
# ============================================================
# Traitement de : tumor_049
# ============================================================
# ✓ WSI chargée avec OpenSlide
#   Dimensions : (97792, 221184)
#   Niveaux : 10
# ✓ 2 annotations trouvées dans le XML
#
# Traitement des annotations...
#
# --- Annotation 1/2: _0 ---
#   Patches cancéreux: 48
#   Patches sains: 15
#
# --- Annotation 2/2: _1 ---
#   Patches cancéreux: 19
#   Patches sains: 11
#
# === RÉSUMÉ ===
# Annotations traitées: 2
# Total patches cancéreux: 67
# Total patches sains: 26
# Ratio cancer/sain: 72.04%
# ✓ Vue d'ensemble sauvegardée : ..\dataset\train_dataset_patches\tumor_049\vue_ensemble_patches.png
# ✓ Traitement terminé pour tumor_049
#
# Fichier 19/21
#
# ============================================================
# Traitement de : tumor_050
# ============================================================
# ✓ WSI chargée avec OpenSlide
#   Dimensions : (97792, 216064)
#   Niveaux : 10
# ✓ 6 annotations trouvées dans le XML
#
# Traitement des annotations...
#
# --- Annotation 1/6: _0 ---
#   Patches cancéreux: 2
#   Patches sains: 0
#
# --- Annotation 2/6: _1 ---
#   Patches cancéreux: 2
#   Patches sains: 0
#
# --- Annotation 3/6: _2 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# --- Annotation 4/6: _3 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# --- Annotation 5/6: _4 ---
#   Patches cancéreux: 148
#   Patches sains: 138
#
# --- Annotation 6/6: _5 ---
#   Patches cancéreux: 1
#   Patches sains: 1
#
# === RÉSUMÉ ===
# Annotations traitées: 6
# Total patches cancéreux: 155
# Total patches sains: 139
# Ratio cancer/sain: 52.72%
# ✓ Vue d'ensemble sauvegardée : ..\dataset\train_dataset_patches\tumor_050\vue_ensemble_patches.png
# ✓ Traitement terminé pour tumor_050
#
# Fichier 20/21
#
# ============================================================
# Traitement de : tumor_067
# ============================================================
# ✓ WSI chargée avec OpenSlide
#   Dimensions : (97792, 221184)
#   Niveaux : 10
# ✓ 1 annotations trouvées dans le XML
#
# Traitement des annotations...
#
# --- Annotation 1/1: _0 ---
#   Patches cancéreux: 3
#   Patches sains: 1
#
# === RÉSUMÉ ===
# Annotations traitées: 1
# Total patches cancéreux: 3
# Total patches sains: 1
# Ratio cancer/sain: 75.00%
# ✓ Vue d'ensemble sauvegardée : ..\dataset\train_dataset_patches\tumor_067\vue_ensemble_patches.png
# ✓ Traitement terminé pour tumor_067
#
# Fichier 21/21
#
# ============================================================
# Traitement de : tumor_111
# ============================================================
# ✓ WSI chargée avec OpenSlide
#   Dimensions : (97792, 220672)
#   Niveaux : 10
# ✓ 9 annotations trouvées dans le XML
#
# Traitement des annotations...
#
# --- Annotation 1/9: Annotation 1 ---
#   Patches cancéreux: 193
#   Patches sains: 185
#
# --- Annotation 2/9: Annotation 2 ---
#   Patches cancéreux: 3
#   Patches sains: 1
#
# --- Annotation 3/9: Annotation 3 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# --- Annotation 4/9: Annotation 4 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# --- Annotation 5/9: Annotation 5 ---
#   Patches cancéreux: 6
#   Patches sains: 0
#
# --- Annotation 6/9: Annotation 6 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# --- Annotation 7/9: Annotation 7 ---
#   Patches cancéreux: 0
#   Patches sains: 0
#
# --- Annotation 8/9: Annotation 8 ---
#   Patches cancéreux: 0
#   Patches sains: 1
#
# --- Annotation 9/9: Annotation 9 ---
#   Patches cancéreux: 1
#   Patches sains: 0
#
# === RÉSUMÉ ===
# Annotations traitées: 9
# Total patches cancéreux: 206
# Total patches sains: 187
# Ratio cancer/sain: 52.42%
# ✓ Vue d'ensemble sauvegardée : ..\dataset\train_dataset_patches\tumor_111\vue_ensemble_patches.png
# ✓ Traitement terminé pour tumor_111
#
# ============================================================
# RÉSUMÉ DU TRAITEMENT BATCH
# ============================================================
# Fichiers traités avec succès : 21/21
# Fichiers avec erreurs : 0/21
#
# Total patches cancéreux : 54180
# Total patches sains : 37770
# Ratio global cancer/sain : 58.92%
#
# Rapports sauvegardés :
#   - ..\dataset\train_dataset_patches\rapport_batch_20250616_174054.json
#   - ..\dataset\train_dataset_patches\rapport_batch_20250616_174054.csv
